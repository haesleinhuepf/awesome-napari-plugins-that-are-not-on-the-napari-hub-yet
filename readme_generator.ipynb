# %%
import pandas as pd

# %%
template = """
### [{reponame}](https://github.com/{orgname}/{reponame})

[![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
[![PyPI](https://img.shields.io/pypi/v/{reponame}.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)

[![codecov](https://codecov.io/gh/{orgname}/{reponame}/branch/master/graph/badge.svg)](https://codecov.io/gh/{orgname}/{reponame})
[![tests](https://github.com/{orgname}/{reponame}/workflows/tests/badge.svg)](https://github.com/{orgname}/{reponame}/actions)
[![Development Status](https://img.shields.io/pypi/status/{reponame}.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
[![](https://img.shields.io/github/release-date-pre/{orgname}/{reponame})](https://github.com/{orgname}/{reponame}/releases)

{description}

---

"""

# %%
table = pd.read_csv("list.csv")
table["order"] = [t.lower().replace("napari-","") for t in table["github repository"]]
table = table.sort_values(by="order",ascending = True) 
table
# Out:
#                   github organization                github repository  \
# 16                            guiwitz        napari-annotation-project
# 35                             adrtsc            napari-blob-detection
# 45                       lowe-lab-ucl                    napari-btrack
# 47                            nel-lab          caiman-napari-prototype
# 33                           jojoelfe                    napari-cistem
# 18                            guiwitz                 napari-convpaint
# 44                         sofroniewn                napari-detectron2
# 49                            jluethi     napari-feature-visualization
# 41                           delnatan                  napari-hdf5-hts
# 37                            psichen             napari-hsafm-browser
# 25                         will-moore                       napari-idr
# 10  fractal-napari-plugins-collection              napari-ijroi-reader
# 20                            ilastik                   napari-ilastik
# 40                    AbigailMcGovern                          iterseg
# 57                          Labelings                  napari-labeling
# 29                          AEttinger                   napari-labfill
# 28      PolarizedLightFieldMicroscopy                        napari-LF
# 1                       haesleinhuepf  napari-mahotas-image-processing
# 6                                 jni                      napari-midi
# 21                      haesleinhuepf            napari-minimal-plugin
# 39                            cudmore                        napari-mm
# 17                            guiwitz            napari-morphodynamics
# 24                           czbiohub   napari-mosquito-bb-annotations
# 12  fractal-napari-plugins-collection        napari_addtional_viewport
# 9                         alisterburt                      napari_etdb
# 13  fractal-napari-plugins-collection               napari_hdf5_reader
# 23                           jayunruh                 napari_jroitools
# 11  fractal-napari-plugins-collection               napari_ptif_reader
# 14  fractal-napari-plugins-collection      napari_tissuemaps_interface
# 15  fractal-napari-plugins-collection                napari_xml_reader
# 7                                 jni                napariboard-proto
# 38                           L-Tellez                          NaparIO
# 19                               nipy                   napari-nibabel
# 34                       miguelarbesu                napari-nmr-reader
# 42                              manzt                     patch-viewer
# 36                           nygctech                          PICASSO
# 0                       haesleinhuepf   napari-pillow-image-processing
# 51                         tlambert03            proto-skimage-widgets
# 46                            pattonw                      napari-pssr
# 2                       haesleinhuepf   napari-pyfast-image-processing
# 32                     sylvainprigent                napari-scixtracer
# 43                         sofroniewn              napari-segmentation
# 48                       DragaDoncila          napari-sentinel-to-zarr
# 26                       DragaDoncila              napari-sentinel-zip
# 4                       kevinyamauchi          napari-skeleton-curator
# 53                            brisvag           napari-skimage-widgets
# 52                         adamltyson                      napari-sldy
# 56                         jo-mueller        napari-spatial-statistics
# 54                            Karol-G         napari-split-blob-labels
# 5                       kevinyamauchi             napari-spot-detector
# 55                       napari-storm                     napari-storm
# 8                         alisterburt                  napari-threedee
# 27                           gatoniel  napari-timeseries-opener-plugin
# 3                       haesleinhuepf                    napari-webcam
# 22                           makepath            napari-xarray-spatial
# 30                       data-exp-lab                        yt-napari
# 31                       data-exp-lab                  napari-ytschema
# 50                            jluethi               napari-zarr-writer
#
#                                     short description  \
# 16  Create projects in napari to annotate series o...
# 35         napari plugin for blob detection in images
# 45                           Napari plugin for btrack
# 47  This plugin interfaces with CaImAn CNMF using ...
# 33  A napari plugin to inspect data within a cisTE...
# 18  Segment images by pixel classification based o...
# 44                       napari plugin for detectron2
# 49  Visualizing feature measurements on label imag...
# 41  simple napari plugin to view multi-well images...
# 37  a napari plugin for viewing high-speed AFM movies
# 25  Napari plugin for opening images from idr.open...
# 10                        Reader for ImageJ ROI files
# 20                          ilastik plugin for napari
# 40  napari plugin for iteratively improving 3D ins...
# 57                        handling overlapping labels
# 29  Napari plugin for creating labels using floodf...
# 28  A temporary plugin with npe2 to use with napar...
# 1   Process images using mahotas from within napar...
# 6           Control napari with a USB MIDI controller
# 21         minimal example plugin (training material)
# 39  Napari plugin to load and visualize 3D image t...
# 17  A napari plugin to use as interface for the mo...
# 24         Napari plugin for bounding box annotations
# 12  Widget to add an additional viewport to visual...
# 9   napari interface for the Caltech electron tomo...
# 13  Widget for multi-scale/multi-dimensional hdf5 ...
# 23  Napari plugins for reading and writing ImageJ ...
# 11      Reader for multi-scale (pyramidal) TIFF files
# 14   Widget to stream images from a TissueMAPS server
# 15  Reader for a series of images enlisted within ...
# 7   Prototype implementation of napari-integrated ...
# 38  Napari plugin that provide better save/load fo...
# 19  A napari plugin that uses nibabel to display m...
# 34                A napari plugin to read NMR spectra
# 42  WIP: A napari plugin to view attention-based h...
# 36           Development of PICASSO plugin for napari
# 0   Process images using pillow from within napari...
# 51  Example adaptor between skimage magicgui and n...
# 46            A plugin for training and applying pssr
# 2   Process images using pyfast from within napari...
# 32  napari plugin for data management with sciXtra...
# 43                         napari segmentation plugin
# 48   Writer plugin for napari to allow saving Sent...
# 26  Plugin to allow loading of SENTINEL zips into ...
# 4                 skeleton curation plugin for napari
# 53  Autogenerated napari widgets for scikit-image ...
# 52             Load slidebook .sldy files into napari
# 56  Analyze architecture of spatially distributed ...
# 54  An adaptive 3D brush for segmentation based on...
# 5           A simple napari plugin for spot detection
# 55                                       STORM plugin
# 8        A suite of 3D interactivity tools for napari
# 27  Simple plugin that opens separate .tif files a...
# 3   View images from your webcam in napari (decomm...
# 22  napari plugin providing interface to xarray-sp...
# 30           A napari plugin for reading data from yt
# 31     experimental plugin for use with the yt schema
# 50                  Napari plugin to write zarr files
#
#                           order
# 16           annotation-project
# 35               blob-detection
# 45                       btrack
# 47             caiman-prototype
# 33                       cistem
# 18                    convpaint
# 44                   detectron2
# 49        feature-visualization
# 41                     hdf5-hts
# 37                hsafm-browser
# 25                          idr
# 10                 ijroi-reader
# 20                      ilastik
# 40                      iterseg
# 57                     labeling
# 29                      labfill
# 28                           lf
# 1      mahotas-image-processing
# 6                          midi
# 21               minimal-plugin
# 39                           mm
# 17               morphodynamics
# 24      mosquito-bb-annotations
# 12    napari_addtional_viewport
# 9                   napari_etdb
# 13           napari_hdf5_reader
# 23             napari_jroitools
# 11           napari_ptif_reader
# 14  napari_tissuemaps_interface
# 15            napari_xml_reader
# 7             napariboard-proto
# 38                      napario
# 19                      nibabel
# 34                   nmr-reader
# 42                 patch-viewer
# 36                      picasso
# 0       pillow-image-processing
# 51        proto-skimage-widgets
# 46                         pssr
# 2       pyfast-image-processing
# 32                   scixtracer
# 43                 segmentation
# 48             sentinel-to-zarr
# 26                 sentinel-zip
# 4              skeleton-curator
# 53              skimage-widgets
# 52                         sldy
# 56           spatial-statistics
# 54            split-blob-labels
# 5                 spot-detector
# 55                        storm
# 8                      threedee
# 27     timeseries-opener-plugin
# 3                        webcam
# 22               xarray-spatial
# 30                    yt-napari
# 31                     ytschema
# 50                  zarr-writer

# %%
table.keys()
# Out:
# Index(['github organization', 'github repository', 'short description',
#        'order'],
#       dtype='object')

# %%
from IPython.display import display, Markdown, Latex
import numpy as np
    
output = ""
for index, r in table.iterrows():
    orgname = r["github organization"]
    reponame = r["github repository"]
    description = r["short description"]
    
    text = template.format(
        orgname=orgname, 
        reponame=reponame,
        description=description,
    )
    
    
    output = output + text
display(Markdown(output))



with open('readme.md', 'w') as f:
    
    with open('readme_header.md', 'r') as header:
        f.write(header.read())
    
    f.write(output)
# Out:
# ### [napari-annotation-project](https://github.com/guiwitz/napari-annotation-project)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-annotation-project.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/guiwitz/napari-annotation-project/branch/master/graph/badge.svg)](https://codecov.io/gh/guiwitz/napari-annotation-project)
# [![tests](https://github.com/guiwitz/napari-annotation-project/workflows/tests/badge.svg)](https://github.com/guiwitz/napari-annotation-project/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-annotation-project.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/guiwitz/napari-annotation-project)](https://github.com/guiwitz/napari-annotation-project/releases)
#
# Create projects in napari to annotate series of images and export annotations
#
# ---
#
#
# ### [napari-blob-detection](https://github.com/adrtsc/napari-blob-detection)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-blob-detection.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/adrtsc/napari-blob-detection/branch/master/graph/badge.svg)](https://codecov.io/gh/adrtsc/napari-blob-detection)
# [![tests](https://github.com/adrtsc/napari-blob-detection/workflows/tests/badge.svg)](https://github.com/adrtsc/napari-blob-detection/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-blob-detection.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/adrtsc/napari-blob-detection)](https://github.com/adrtsc/napari-blob-detection/releases)
#
# napari plugin for blob detection in images
#
# ---
#
#
# ### [napari-btrack](https://github.com/lowe-lab-ucl/napari-btrack)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-btrack.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/lowe-lab-ucl/napari-btrack/branch/master/graph/badge.svg)](https://codecov.io/gh/lowe-lab-ucl/napari-btrack)
# [![tests](https://github.com/lowe-lab-ucl/napari-btrack/workflows/tests/badge.svg)](https://github.com/lowe-lab-ucl/napari-btrack/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-btrack.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/lowe-lab-ucl/napari-btrack)](https://github.com/lowe-lab-ucl/napari-btrack/releases)
#
# Napari plugin for btrack
#
# ---
#
#
# ### [caiman-napari-prototype](https://github.com/nel-lab/caiman-napari-prototype)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/caiman-napari-prototype.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/nel-lab/caiman-napari-prototype/branch/master/graph/badge.svg)](https://codecov.io/gh/nel-lab/caiman-napari-prototype)
# [![tests](https://github.com/nel-lab/caiman-napari-prototype/workflows/tests/badge.svg)](https://github.com/nel-lab/caiman-napari-prototype/actions)
# [![Development Status](https://img.shields.io/pypi/status/caiman-napari-prototype.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/nel-lab/caiman-napari-prototype)](https://github.com/nel-lab/caiman-napari-prototype/releases)
#
# This plugin interfaces with CaImAn CNMF using QProcess and displays the spatial components using napari.layers.shapes.
#
# ---
#
#
# ### [napari-cistem](https://github.com/jojoelfe/napari-cistem)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-cistem.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jojoelfe/napari-cistem/branch/master/graph/badge.svg)](https://codecov.io/gh/jojoelfe/napari-cistem)
# [![tests](https://github.com/jojoelfe/napari-cistem/workflows/tests/badge.svg)](https://github.com/jojoelfe/napari-cistem/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-cistem.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jojoelfe/napari-cistem)](https://github.com/jojoelfe/napari-cistem/releases)
#
# A napari plugin to inspect data within a cisTEM project
#
# ---
#
#
# ### [napari-convpaint](https://github.com/guiwitz/napari-convpaint)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-convpaint.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/guiwitz/napari-convpaint/branch/master/graph/badge.svg)](https://codecov.io/gh/guiwitz/napari-convpaint)
# [![tests](https://github.com/guiwitz/napari-convpaint/workflows/tests/badge.svg)](https://github.com/guiwitz/napari-convpaint/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-convpaint.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/guiwitz/napari-convpaint)](https://github.com/guiwitz/napari-convpaint/releases)
#
# Segment images by pixel classification based on pre-trained convolutional layer feature extraction
#
# ---
#
#
# ### [napari-detectron2](https://github.com/sofroniewn/napari-detectron2)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-detectron2.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/sofroniewn/napari-detectron2/branch/master/graph/badge.svg)](https://codecov.io/gh/sofroniewn/napari-detectron2)
# [![tests](https://github.com/sofroniewn/napari-detectron2/workflows/tests/badge.svg)](https://github.com/sofroniewn/napari-detectron2/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-detectron2.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/sofroniewn/napari-detectron2)](https://github.com/sofroniewn/napari-detectron2/releases)
#
# napari plugin for detectron2
#
# ---
#
#
# ### [napari-feature-visualization](https://github.com/jluethi/napari-feature-visualization)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-feature-visualization.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jluethi/napari-feature-visualization/branch/master/graph/badge.svg)](https://codecov.io/gh/jluethi/napari-feature-visualization)
# [![tests](https://github.com/jluethi/napari-feature-visualization/workflows/tests/badge.svg)](https://github.com/jluethi/napari-feature-visualization/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-feature-visualization.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jluethi/napari-feature-visualization)](https://github.com/jluethi/napari-feature-visualization/releases)
#
# Visualizing feature measurements on label images in napari
#
# ---
#
#
# ### [napari-hdf5-hts](https://github.com/delnatan/napari-hdf5-hts)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-hdf5-hts.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/delnatan/napari-hdf5-hts/branch/master/graph/badge.svg)](https://codecov.io/gh/delnatan/napari-hdf5-hts)
# [![tests](https://github.com/delnatan/napari-hdf5-hts/workflows/tests/badge.svg)](https://github.com/delnatan/napari-hdf5-hts/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-hdf5-hts.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/delnatan/napari-hdf5-hts)](https://github.com/delnatan/napari-hdf5-hts/releases)
#
# simple napari plugin to view multi-well images in HDF5 format
#
# ---
#
#
# ### [napari-hsafm-browser](https://github.com/psichen/napari-hsafm-browser)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-hsafm-browser.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/psichen/napari-hsafm-browser/branch/master/graph/badge.svg)](https://codecov.io/gh/psichen/napari-hsafm-browser)
# [![tests](https://github.com/psichen/napari-hsafm-browser/workflows/tests/badge.svg)](https://github.com/psichen/napari-hsafm-browser/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-hsafm-browser.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/psichen/napari-hsafm-browser)](https://github.com/psichen/napari-hsafm-browser/releases)
#
# a napari plugin for viewing high-speed AFM movies
#
# ---
#
#
# ### [napari-idr](https://github.com/will-moore/napari-idr)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-idr.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/will-moore/napari-idr/branch/master/graph/badge.svg)](https://codecov.io/gh/will-moore/napari-idr)
# [![tests](https://github.com/will-moore/napari-idr/workflows/tests/badge.svg)](https://github.com/will-moore/napari-idr/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-idr.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/will-moore/napari-idr)](https://github.com/will-moore/napari-idr/releases)
#
# Napari plugin for opening images from idr.openmicroscopy.org
#
# ---
#
#
# ### [napari-ijroi-reader](https://github.com/fractal-napari-plugins-collection/napari-ijroi-reader)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-ijroi-reader.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari-ijroi-reader/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari-ijroi-reader)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari-ijroi-reader/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari-ijroi-reader/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-ijroi-reader.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari-ijroi-reader)](https://github.com/fractal-napari-plugins-collection/napari-ijroi-reader/releases)
#
# Reader for ImageJ ROI files
#
# ---
#
#
# ### [napari-ilastik](https://github.com/ilastik/napari-ilastik)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-ilastik.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/ilastik/napari-ilastik/branch/master/graph/badge.svg)](https://codecov.io/gh/ilastik/napari-ilastik)
# [![tests](https://github.com/ilastik/napari-ilastik/workflows/tests/badge.svg)](https://github.com/ilastik/napari-ilastik/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-ilastik.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/ilastik/napari-ilastik)](https://github.com/ilastik/napari-ilastik/releases)
#
# ilastik plugin for napari
#
# ---
#
#
# ### [iterseg](https://github.com/AbigailMcGovern/iterseg)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/iterseg.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/AbigailMcGovern/iterseg/branch/master/graph/badge.svg)](https://codecov.io/gh/AbigailMcGovern/iterseg)
# [![tests](https://github.com/AbigailMcGovern/iterseg/workflows/tests/badge.svg)](https://github.com/AbigailMcGovern/iterseg/actions)
# [![Development Status](https://img.shields.io/pypi/status/iterseg.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/AbigailMcGovern/iterseg)](https://github.com/AbigailMcGovern/iterseg/releases)
#
# napari plugin for iteratively improving 3D instance segmentation of cells (u-net x watershed)
#
# ---
#
#
# ### [napari-labeling](https://github.com/Labelings/napari-labeling)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-labeling.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/Labelings/napari-labeling/branch/master/graph/badge.svg)](https://codecov.io/gh/Labelings/napari-labeling)
# [![tests](https://github.com/Labelings/napari-labeling/workflows/tests/badge.svg)](https://github.com/Labelings/napari-labeling/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-labeling.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/Labelings/napari-labeling)](https://github.com/Labelings/napari-labeling/releases)
#
# handling overlapping labels
#
# ---
#
#
# ### [napari-labfill](https://github.com/AEttinger/napari-labfill)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-labfill.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/AEttinger/napari-labfill/branch/master/graph/badge.svg)](https://codecov.io/gh/AEttinger/napari-labfill)
# [![tests](https://github.com/AEttinger/napari-labfill/workflows/tests/badge.svg)](https://github.com/AEttinger/napari-labfill/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-labfill.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/AEttinger/napari-labfill)](https://github.com/AEttinger/napari-labfill/releases)
#
# Napari plugin for creating labels using floodfill.
#
# ---
#
#
# ### [napari-LF](https://github.com/PolarizedLightFieldMicroscopy/napari-LF)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-LF.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/PolarizedLightFieldMicroscopy/napari-LF/branch/master/graph/badge.svg)](https://codecov.io/gh/PolarizedLightFieldMicroscopy/napari-LF)
# [![tests](https://github.com/PolarizedLightFieldMicroscopy/napari-LF/workflows/tests/badge.svg)](https://github.com/PolarizedLightFieldMicroscopy/napari-LF/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-LF.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/PolarizedLightFieldMicroscopy/napari-LF)](https://github.com/PolarizedLightFieldMicroscopy/napari-LF/releases)
#
# A temporary plugin with npe2 to use with napari in the process of developing a light field imaging plugin
#
# ---
#
#
# ### [napari-mahotas-image-processing](https://github.com/haesleinhuepf/napari-mahotas-image-processing)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-mahotas-image-processing.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/haesleinhuepf/napari-mahotas-image-processing/branch/master/graph/badge.svg)](https://codecov.io/gh/haesleinhuepf/napari-mahotas-image-processing)
# [![tests](https://github.com/haesleinhuepf/napari-mahotas-image-processing/workflows/tests/badge.svg)](https://github.com/haesleinhuepf/napari-mahotas-image-processing/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-mahotas-image-processing.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/haesleinhuepf/napari-mahotas-image-processing)](https://github.com/haesleinhuepf/napari-mahotas-image-processing/releases)
#
# Process images using mahotas from within napari (experimental just playing plugin)
#
# ---
#
#
# ### [napari-midi](https://github.com/jni/napari-midi)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-midi.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jni/napari-midi/branch/master/graph/badge.svg)](https://codecov.io/gh/jni/napari-midi)
# [![tests](https://github.com/jni/napari-midi/workflows/tests/badge.svg)](https://github.com/jni/napari-midi/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-midi.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jni/napari-midi)](https://github.com/jni/napari-midi/releases)
#
# Control napari with a USB MIDI controller
#
# ---
#
#
# ### [napari-minimal-plugin](https://github.com/haesleinhuepf/napari-minimal-plugin)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-minimal-plugin.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/haesleinhuepf/napari-minimal-plugin/branch/master/graph/badge.svg)](https://codecov.io/gh/haesleinhuepf/napari-minimal-plugin)
# [![tests](https://github.com/haesleinhuepf/napari-minimal-plugin/workflows/tests/badge.svg)](https://github.com/haesleinhuepf/napari-minimal-plugin/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-minimal-plugin.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/haesleinhuepf/napari-minimal-plugin)](https://github.com/haesleinhuepf/napari-minimal-plugin/releases)
#
# minimal example plugin (training material)
#
# ---
#
#
# ### [napari-mm](https://github.com/cudmore/napari-mm)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-mm.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/cudmore/napari-mm/branch/master/graph/badge.svg)](https://codecov.io/gh/cudmore/napari-mm)
# [![tests](https://github.com/cudmore/napari-mm/workflows/tests/badge.svg)](https://github.com/cudmore/napari-mm/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-mm.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/cudmore/napari-mm)](https://github.com/cudmore/napari-mm/releases)
#
# Napari plugin to load and visualize 3D image time series saved by Map Manager
#
# ---
#
#
# ### [napari-morphodynamics](https://github.com/guiwitz/napari-morphodynamics)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-morphodynamics.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/guiwitz/napari-morphodynamics/branch/master/graph/badge.svg)](https://codecov.io/gh/guiwitz/napari-morphodynamics)
# [![tests](https://github.com/guiwitz/napari-morphodynamics/workflows/tests/badge.svg)](https://github.com/guiwitz/napari-morphodynamics/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-morphodynamics.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/guiwitz/napari-morphodynamics)](https://github.com/guiwitz/napari-morphodynamics/releases)
#
# A napari plugin to use as interface for the morphodynamics package
#
# ---
#
#
# ### [napari-mosquito-bb-annotations](https://github.com/czbiohub/napari-mosquito-bb-annotations)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-mosquito-bb-annotations.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/czbiohub/napari-mosquito-bb-annotations/branch/master/graph/badge.svg)](https://codecov.io/gh/czbiohub/napari-mosquito-bb-annotations)
# [![tests](https://github.com/czbiohub/napari-mosquito-bb-annotations/workflows/tests/badge.svg)](https://github.com/czbiohub/napari-mosquito-bb-annotations/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-mosquito-bb-annotations.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/czbiohub/napari-mosquito-bb-annotations)](https://github.com/czbiohub/napari-mosquito-bb-annotations/releases)
#
# Napari plugin for bounding box annotations
#
# ---
#
#
# ### [napari_addtional_viewport](https://github.com/fractal-napari-plugins-collection/napari_addtional_viewport)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_addtional_viewport.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari_addtional_viewport/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari_addtional_viewport)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari_addtional_viewport/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari_addtional_viewport/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_addtional_viewport.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari_addtional_viewport)](https://github.com/fractal-napari-plugins-collection/napari_addtional_viewport/releases)
#
# Widget to add an additional viewport to visualize on a specific shape
#
# ---
#
#
# ### [napari_etdb](https://github.com/alisterburt/napari_etdb)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_etdb.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/alisterburt/napari_etdb/branch/master/graph/badge.svg)](https://codecov.io/gh/alisterburt/napari_etdb)
# [![tests](https://github.com/alisterburt/napari_etdb/workflows/tests/badge.svg)](https://github.com/alisterburt/napari_etdb/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_etdb.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/alisterburt/napari_etdb)](https://github.com/alisterburt/napari_etdb/releases)
#
# napari interface for the Caltech electron tomography database
#
# ---
#
#
# ### [napari_hdf5_reader](https://github.com/fractal-napari-plugins-collection/napari_hdf5_reader)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_hdf5_reader.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari_hdf5_reader/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari_hdf5_reader)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari_hdf5_reader/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari_hdf5_reader/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_hdf5_reader.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari_hdf5_reader)](https://github.com/fractal-napari-plugins-collection/napari_hdf5_reader/releases)
#
# Widget for multi-scale/multi-dimensional hdf5 files
#
# ---
#
#
# ### [napari_jroitools](https://github.com/jayunruh/napari_jroitools)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_jroitools.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jayunruh/napari_jroitools/branch/master/graph/badge.svg)](https://codecov.io/gh/jayunruh/napari_jroitools)
# [![tests](https://github.com/jayunruh/napari_jroitools/workflows/tests/badge.svg)](https://github.com/jayunruh/napari_jroitools/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_jroitools.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jayunruh/napari_jroitools)](https://github.com/jayunruh/napari_jroitools/releases)
#
# Napari plugins for reading and writing ImageJ roi files and creating image profiles.
#
# ---
#
#
# ### [napari_ptif_reader](https://github.com/fractal-napari-plugins-collection/napari_ptif_reader)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_ptif_reader.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari_ptif_reader/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari_ptif_reader)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari_ptif_reader/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari_ptif_reader/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_ptif_reader.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari_ptif_reader)](https://github.com/fractal-napari-plugins-collection/napari_ptif_reader/releases)
#
# Reader for multi-scale (pyramidal) TIFF files
#
# ---
#
#
# ### [napari_tissuemaps_interface](https://github.com/fractal-napari-plugins-collection/napari_tissuemaps_interface)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_tissuemaps_interface.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari_tissuemaps_interface/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari_tissuemaps_interface)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari_tissuemaps_interface/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari_tissuemaps_interface/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_tissuemaps_interface.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari_tissuemaps_interface)](https://github.com/fractal-napari-plugins-collection/napari_tissuemaps_interface/releases)
#
# Widget to stream images from a TissueMAPS server
#
# ---
#
#
# ### [napari_xml_reader](https://github.com/fractal-napari-plugins-collection/napari_xml_reader)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari_xml_reader.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/fractal-napari-plugins-collection/napari_xml_reader/branch/master/graph/badge.svg)](https://codecov.io/gh/fractal-napari-plugins-collection/napari_xml_reader)
# [![tests](https://github.com/fractal-napari-plugins-collection/napari_xml_reader/workflows/tests/badge.svg)](https://github.com/fractal-napari-plugins-collection/napari_xml_reader/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari_xml_reader.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/fractal-napari-plugins-collection/napari_xml_reader)](https://github.com/fractal-napari-plugins-collection/napari_xml_reader/releases)
#
# Reader for a series of images enlisted within an XML files
#
# ---
#
#
# ### [napariboard-proto](https://github.com/jni/napariboard-proto)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napariboard-proto.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jni/napariboard-proto/branch/master/graph/badge.svg)](https://codecov.io/gh/jni/napariboard-proto)
# [![tests](https://github.com/jni/napariboard-proto/workflows/tests/badge.svg)](https://github.com/jni/napariboard-proto/actions)
# [![Development Status](https://img.shields.io/pypi/status/napariboard-proto.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jni/napariboard-proto)](https://github.com/jni/napariboard-proto/releases)
#
# Prototype implementation of napari-integrated CNN training viewer
#
# ---
#
#
# ### [NaparIO](https://github.com/L-Tellez/NaparIO)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/NaparIO.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/L-Tellez/NaparIO/branch/master/graph/badge.svg)](https://codecov.io/gh/L-Tellez/NaparIO)
# [![tests](https://github.com/L-Tellez/NaparIO/workflows/tests/badge.svg)](https://github.com/L-Tellez/NaparIO/actions)
# [![Development Status](https://img.shields.io/pypi/status/NaparIO.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/L-Tellez/NaparIO)](https://github.com/L-Tellez/NaparIO/releases)
#
# Napari plugin that provide better save/load for all opened layers
#
# ---
#
#
# ### [napari-nibabel](https://github.com/nipy/napari-nibabel)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-nibabel.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/nipy/napari-nibabel/branch/master/graph/badge.svg)](https://codecov.io/gh/nipy/napari-nibabel)
# [![tests](https://github.com/nipy/napari-nibabel/workflows/tests/badge.svg)](https://github.com/nipy/napari-nibabel/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-nibabel.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/nipy/napari-nibabel)](https://github.com/nipy/napari-nibabel/releases)
#
# A napari plugin that uses nibabel to display medical images (NIFTI1 NIFTI2 ANALYZE Philips PAR/REC MINC1 MINC2 AFNI BRIK/HEAD and MGH/MGZ.)
#
# ---
#
#
# ### [napari-nmr-reader](https://github.com/miguelarbesu/napari-nmr-reader)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-nmr-reader.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/miguelarbesu/napari-nmr-reader/branch/master/graph/badge.svg)](https://codecov.io/gh/miguelarbesu/napari-nmr-reader)
# [![tests](https://github.com/miguelarbesu/napari-nmr-reader/workflows/tests/badge.svg)](https://github.com/miguelarbesu/napari-nmr-reader/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-nmr-reader.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/miguelarbesu/napari-nmr-reader)](https://github.com/miguelarbesu/napari-nmr-reader/releases)
#
# A napari plugin to read NMR spectra
#
# ---
#
#
# ### [patch-viewer](https://github.com/manzt/patch-viewer)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/patch-viewer.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/manzt/patch-viewer/branch/master/graph/badge.svg)](https://codecov.io/gh/manzt/patch-viewer)
# [![tests](https://github.com/manzt/patch-viewer/workflows/tests/badge.svg)](https://github.com/manzt/patch-viewer/actions)
# [![Development Status](https://img.shields.io/pypi/status/patch-viewer.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/manzt/patch-viewer)](https://github.com/manzt/patch-viewer/releases)
#
# WIP: A napari plugin to view attention-based heatmaps for whole slide images
#
# ---
#
#
# ### [PICASSO](https://github.com/nygctech/PICASSO)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/PICASSO.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/nygctech/PICASSO/branch/master/graph/badge.svg)](https://codecov.io/gh/nygctech/PICASSO)
# [![tests](https://github.com/nygctech/PICASSO/workflows/tests/badge.svg)](https://github.com/nygctech/PICASSO/actions)
# [![Development Status](https://img.shields.io/pypi/status/PICASSO.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/nygctech/PICASSO)](https://github.com/nygctech/PICASSO/releases)
#
# Development of PICASSO plugin for napari
#
# ---
#
#
# ### [napari-pillow-image-processing](https://github.com/haesleinhuepf/napari-pillow-image-processing)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-pillow-image-processing.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/haesleinhuepf/napari-pillow-image-processing/branch/master/graph/badge.svg)](https://codecov.io/gh/haesleinhuepf/napari-pillow-image-processing)
# [![tests](https://github.com/haesleinhuepf/napari-pillow-image-processing/workflows/tests/badge.svg)](https://github.com/haesleinhuepf/napari-pillow-image-processing/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-pillow-image-processing.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/haesleinhuepf/napari-pillow-image-processing)](https://github.com/haesleinhuepf/napari-pillow-image-processing/releases)
#
# Process images using pillow from within napari (experimental just playing plugin)
#
# ---
#
#
# ### [proto-skimage-widgets](https://github.com/tlambert03/proto-skimage-widgets)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/proto-skimage-widgets.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/tlambert03/proto-skimage-widgets/branch/master/graph/badge.svg)](https://codecov.io/gh/tlambert03/proto-skimage-widgets)
# [![tests](https://github.com/tlambert03/proto-skimage-widgets/workflows/tests/badge.svg)](https://github.com/tlambert03/proto-skimage-widgets/actions)
# [![Development Status](https://img.shields.io/pypi/status/proto-skimage-widgets.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/tlambert03/proto-skimage-widgets)](https://github.com/tlambert03/proto-skimage-widgets/releases)
#
# Example adaptor between skimage magicgui and napari WORK IN PROGRESS
#
# ---
#
#
# ### [napari-pssr](https://github.com/pattonw/napari-pssr)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-pssr.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/pattonw/napari-pssr/branch/master/graph/badge.svg)](https://codecov.io/gh/pattonw/napari-pssr)
# [![tests](https://github.com/pattonw/napari-pssr/workflows/tests/badge.svg)](https://github.com/pattonw/napari-pssr/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-pssr.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/pattonw/napari-pssr)](https://github.com/pattonw/napari-pssr/releases)
#
# A plugin for training and applying pssr
#
# ---
#
#
# ### [napari-pyfast-image-processing](https://github.com/haesleinhuepf/napari-pyfast-image-processing)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-pyfast-image-processing.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/haesleinhuepf/napari-pyfast-image-processing/branch/master/graph/badge.svg)](https://codecov.io/gh/haesleinhuepf/napari-pyfast-image-processing)
# [![tests](https://github.com/haesleinhuepf/napari-pyfast-image-processing/workflows/tests/badge.svg)](https://github.com/haesleinhuepf/napari-pyfast-image-processing/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-pyfast-image-processing.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/haesleinhuepf/napari-pyfast-image-processing)](https://github.com/haesleinhuepf/napari-pyfast-image-processing/releases)
#
# Process images using pyfast from within napari (experimental just playing plugin)
#
# ---
#
#
# ### [napari-scixtracer](https://github.com/sylvainprigent/napari-scixtracer)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-scixtracer.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/sylvainprigent/napari-scixtracer/branch/master/graph/badge.svg)](https://codecov.io/gh/sylvainprigent/napari-scixtracer)
# [![tests](https://github.com/sylvainprigent/napari-scixtracer/workflows/tests/badge.svg)](https://github.com/sylvainprigent/napari-scixtracer/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-scixtracer.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/sylvainprigent/napari-scixtracer)](https://github.com/sylvainprigent/napari-scixtracer/releases)
#
# napari plugin for data management with sciXtracer library
#
# ---
#
#
# ### [napari-segmentation](https://github.com/sofroniewn/napari-segmentation)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-segmentation.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/sofroniewn/napari-segmentation/branch/master/graph/badge.svg)](https://codecov.io/gh/sofroniewn/napari-segmentation)
# [![tests](https://github.com/sofroniewn/napari-segmentation/workflows/tests/badge.svg)](https://github.com/sofroniewn/napari-segmentation/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-segmentation.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/sofroniewn/napari-segmentation)](https://github.com/sofroniewn/napari-segmentation/releases)
#
# napari segmentation plugin
#
# ---
#
#
# ### [napari-sentinel-to-zarr](https://github.com/DragaDoncila/napari-sentinel-to-zarr)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-sentinel-to-zarr.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/DragaDoncila/napari-sentinel-to-zarr/branch/master/graph/badge.svg)](https://codecov.io/gh/DragaDoncila/napari-sentinel-to-zarr)
# [![tests](https://github.com/DragaDoncila/napari-sentinel-to-zarr/workflows/tests/badge.svg)](https://github.com/DragaDoncila/napari-sentinel-to-zarr/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-sentinel-to-zarr.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/DragaDoncila/napari-sentinel-to-zarr)](https://github.com/DragaDoncila/napari-sentinel-to-zarr/releases)
#
#  Writer plugin for napari to allow saving Sentinel tiffs out to ome-zarr
#
# ---
#
#
# ### [napari-sentinel-zip](https://github.com/DragaDoncila/napari-sentinel-zip)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-sentinel-zip.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/DragaDoncila/napari-sentinel-zip/branch/master/graph/badge.svg)](https://codecov.io/gh/DragaDoncila/napari-sentinel-zip)
# [![tests](https://github.com/DragaDoncila/napari-sentinel-zip/workflows/tests/badge.svg)](https://github.com/DragaDoncila/napari-sentinel-zip/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-sentinel-zip.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/DragaDoncila/napari-sentinel-zip)](https://github.com/DragaDoncila/napari-sentinel-zip/releases)
#
# Plugin to allow loading of SENTINEL zips into napari directly
#
# ---
#
#
# ### [napari-skeleton-curator](https://github.com/kevinyamauchi/napari-skeleton-curator)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-skeleton-curator.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/kevinyamauchi/napari-skeleton-curator/branch/master/graph/badge.svg)](https://codecov.io/gh/kevinyamauchi/napari-skeleton-curator)
# [![tests](https://github.com/kevinyamauchi/napari-skeleton-curator/workflows/tests/badge.svg)](https://github.com/kevinyamauchi/napari-skeleton-curator/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-skeleton-curator.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/kevinyamauchi/napari-skeleton-curator)](https://github.com/kevinyamauchi/napari-skeleton-curator/releases)
#
# skeleton curation plugin for napari
#
# ---
#
#
# ### [napari-skimage-widgets](https://github.com/brisvag/napari-skimage-widgets)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-skimage-widgets.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/brisvag/napari-skimage-widgets/branch/master/graph/badge.svg)](https://codecov.io/gh/brisvag/napari-skimage-widgets)
# [![tests](https://github.com/brisvag/napari-skimage-widgets/workflows/tests/badge.svg)](https://github.com/brisvag/napari-skimage-widgets/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-skimage-widgets.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/brisvag/napari-skimage-widgets)](https://github.com/brisvag/napari-skimage-widgets/releases)
#
# Autogenerated napari widgets for scikit-image functions.
#
# ---
#
#
# ### [napari-sldy](https://github.com/adamltyson/napari-sldy)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-sldy.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/adamltyson/napari-sldy/branch/master/graph/badge.svg)](https://codecov.io/gh/adamltyson/napari-sldy)
# [![tests](https://github.com/adamltyson/napari-sldy/workflows/tests/badge.svg)](https://github.com/adamltyson/napari-sldy/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-sldy.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/adamltyson/napari-sldy)](https://github.com/adamltyson/napari-sldy/releases)
#
# Load slidebook .sldy files into napari
#
# ---
#
#
# ### [napari-spatial-statistics](https://github.com/jo-mueller/napari-spatial-statistics)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-spatial-statistics.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jo-mueller/napari-spatial-statistics/branch/master/graph/badge.svg)](https://codecov.io/gh/jo-mueller/napari-spatial-statistics)
# [![tests](https://github.com/jo-mueller/napari-spatial-statistics/workflows/tests/badge.svg)](https://github.com/jo-mueller/napari-spatial-statistics/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-spatial-statistics.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jo-mueller/napari-spatial-statistics)](https://github.com/jo-mueller/napari-spatial-statistics/releases)
#
# Analyze architecture of spatially distributed objects.
#
# ---
#
#
# ### [napari-split-blob-labels](https://github.com/Karol-G/napari-split-blob-labels)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-split-blob-labels.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/Karol-G/napari-split-blob-labels/branch/master/graph/badge.svg)](https://codecov.io/gh/Karol-G/napari-split-blob-labels)
# [![tests](https://github.com/Karol-G/napari-split-blob-labels/workflows/tests/badge.svg)](https://github.com/Karol-G/napari-split-blob-labels/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-split-blob-labels.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/Karol-G/napari-split-blob-labels)](https://github.com/Karol-G/napari-split-blob-labels/releases)
#
# An adaptive 3D brush for segmentation based on local region growing
#
# ---
#
#
# ### [napari-spot-detector](https://github.com/kevinyamauchi/napari-spot-detector)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-spot-detector.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/kevinyamauchi/napari-spot-detector/branch/master/graph/badge.svg)](https://codecov.io/gh/kevinyamauchi/napari-spot-detector)
# [![tests](https://github.com/kevinyamauchi/napari-spot-detector/workflows/tests/badge.svg)](https://github.com/kevinyamauchi/napari-spot-detector/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-spot-detector.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/kevinyamauchi/napari-spot-detector)](https://github.com/kevinyamauchi/napari-spot-detector/releases)
#
# A simple napari plugin for spot detection
#
# ---
#
#
# ### [napari-storm](https://github.com/napari-storm/napari-storm)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-storm.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/napari-storm/napari-storm/branch/master/graph/badge.svg)](https://codecov.io/gh/napari-storm/napari-storm)
# [![tests](https://github.com/napari-storm/napari-storm/workflows/tests/badge.svg)](https://github.com/napari-storm/napari-storm/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-storm.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/napari-storm/napari-storm)](https://github.com/napari-storm/napari-storm/releases)
#
# STORM plugin
#
# ---
#
#
# ### [napari-threedee](https://github.com/alisterburt/napari-threedee)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-threedee.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/alisterburt/napari-threedee/branch/master/graph/badge.svg)](https://codecov.io/gh/alisterburt/napari-threedee)
# [![tests](https://github.com/alisterburt/napari-threedee/workflows/tests/badge.svg)](https://github.com/alisterburt/napari-threedee/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-threedee.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/alisterburt/napari-threedee)](https://github.com/alisterburt/napari-threedee/releases)
#
# A suite of 3D interactivity tools for napari
#
# ---
#
#
# ### [napari-timeseries-opener-plugin](https://github.com/gatoniel/napari-timeseries-opener-plugin)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-timeseries-opener-plugin.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/gatoniel/napari-timeseries-opener-plugin/branch/master/graph/badge.svg)](https://codecov.io/gh/gatoniel/napari-timeseries-opener-plugin)
# [![tests](https://github.com/gatoniel/napari-timeseries-opener-plugin/workflows/tests/badge.svg)](https://github.com/gatoniel/napari-timeseries-opener-plugin/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-timeseries-opener-plugin.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/gatoniel/napari-timeseries-opener-plugin)](https://github.com/gatoniel/napari-timeseries-opener-plugin/releases)
#
# Simple plugin that opens separate .tif files as a 3-dimensional layer.
#
# ---
#
#
# ### [napari-webcam](https://github.com/haesleinhuepf/napari-webcam)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-webcam.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/haesleinhuepf/napari-webcam/branch/master/graph/badge.svg)](https://codecov.io/gh/haesleinhuepf/napari-webcam)
# [![tests](https://github.com/haesleinhuepf/napari-webcam/workflows/tests/badge.svg)](https://github.com/haesleinhuepf/napari-webcam/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-webcam.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/haesleinhuepf/napari-webcam)](https://github.com/haesleinhuepf/napari-webcam/releases)
#
# View images from your webcam in napari (decommissioned plugin/ archived)
#
# ---
#
#
# ### [napari-xarray-spatial](https://github.com/makepath/napari-xarray-spatial)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-xarray-spatial.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/makepath/napari-xarray-spatial/branch/master/graph/badge.svg)](https://codecov.io/gh/makepath/napari-xarray-spatial)
# [![tests](https://github.com/makepath/napari-xarray-spatial/workflows/tests/badge.svg)](https://github.com/makepath/napari-xarray-spatial/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-xarray-spatial.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/makepath/napari-xarray-spatial)](https://github.com/makepath/napari-xarray-spatial/releases)
#
# napari plugin providing interface to xarray-spatial functions
#
# ---
#
#
# ### [yt-napari](https://github.com/data-exp-lab/yt-napari)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/yt-napari.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/data-exp-lab/yt-napari/branch/master/graph/badge.svg)](https://codecov.io/gh/data-exp-lab/yt-napari)
# [![tests](https://github.com/data-exp-lab/yt-napari/workflows/tests/badge.svg)](https://github.com/data-exp-lab/yt-napari/actions)
# [![Development Status](https://img.shields.io/pypi/status/yt-napari.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/data-exp-lab/yt-napari)](https://github.com/data-exp-lab/yt-napari/releases)
#
# A napari plugin for reading data from yt
#
# ---
#
#
# ### [napari-ytschema](https://github.com/data-exp-lab/napari-ytschema)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-ytschema.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/data-exp-lab/napari-ytschema/branch/master/graph/badge.svg)](https://codecov.io/gh/data-exp-lab/napari-ytschema)
# [![tests](https://github.com/data-exp-lab/napari-ytschema/workflows/tests/badge.svg)](https://github.com/data-exp-lab/napari-ytschema/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-ytschema.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/data-exp-lab/napari-ytschema)](https://github.com/data-exp-lab/napari-ytschema/releases)
#
# experimental plugin for use with the yt schema
#
# ---
#
#
# ### [napari-zarr-writer](https://github.com/jluethi/napari-zarr-writer)
#
# [![napari hub](https://img.shields.io/endpoint?url=https://api.napari-hub.org/shields/napari-mm)](https://napari-hub.org/plugins/napari-mm)
# [![PyPI](https://img.shields.io/pypi/v/napari-zarr-writer.svg?color=green)](https://pypi.org/project/napari-brightness-contrast)
#
# [![codecov](https://codecov.io/gh/jluethi/napari-zarr-writer/branch/master/graph/badge.svg)](https://codecov.io/gh/jluethi/napari-zarr-writer)
# [![tests](https://github.com/jluethi/napari-zarr-writer/workflows/tests/badge.svg)](https://github.com/jluethi/napari-zarr-writer/actions)
# [![Development Status](https://img.shields.io/pypi/status/napari-zarr-writer.svg)](https://en.wikipedia.org/wiki/Software_release_life_cycle#Alpha)
# [![](https://img.shields.io/github/release-date-pre/jluethi/napari-zarr-writer)](https://github.com/jluethi/napari-zarr-writer/releases)
#
# Napari plugin to write zarr files
#
# ---
